# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\saqib\\OneDrive\\Desktop\\production-grade-wine-predictor\\research'

# %%
os.chdir("../")
# %pwd
# Out:
# 'c:\\Users\\saqib\\OneDrive\\Desktop\\production-grade-wine-predictor'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.productiongradewinepredictor.constants import *
from src.productiongradewinepredictor.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
        )

        return data_transformation_config

# %%
import os
from src.productiongradewinepredictor import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in .\venv\Lib\site-packages (from scikit-learn) (2.4.3)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: joblib>=1.3.0 in .\venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 2.2 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 3.4 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 2.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.1 MB 2.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 2.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 2.6 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 1.9 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.1 MB 2.1 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.1 MB 2.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 2.2 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.2 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.1 MB 1.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.1 MB 1.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.1 MB 2.0 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 2.0 MB/s  0:00:04
# Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/37.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/37.3 MB 1.8 MB/s eta 0:00:21
#    - -------------------------------------- 1.0/37.3 MB 1.9 MB/s eta 0:00:20
#    - -------------------------------------- 1.3/37.3 MB 1.8 MB/s eta 0:00:20
#    - -------------------------------------- 1.8/37.3 MB 1.8 MB/s eta 0:00:20
#    -- ------------------------------------- 2.1/37.3 MB 1.9 MB/s eta 0:00:19
#    -- ------------------------------------- 2.6/37.3 MB 1.9 MB/s eta 0:00:19
#    --- ------------------------------------ 2.9/37.3 MB 1.9 MB/s eta 0:00:19
#    --- ------------------------------------ 3.4/37.3 MB 1.9 MB/s eta 0:00:18
#    --- ------------------------------------ 3.7/37.3 MB 1.9 MB/s eta 0:00:18
#    ---- ----------------------------------- 4.2/37.3 MB 1.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 4.7/37.3 MB 1.9 MB/s eta 0:00:17
#    ----- ---------------------------------- 5.0/37.3 MB 1.9 MB/s eta 0:00:17
#    ----- ---------------------------------- 5.5/37.3 MB 1.9 MB/s eta 0:00:17
#    ------ --------------------------------- 6.0/37.3 MB 1.9 MB/s eta 0:00:17
#    ------ --------------------------------- 6.3/37.3 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 6.8/37.3 MB 2.0 MB/s eta 0:00:16
#    ------- -------------------------------- 7.1/37.3 MB 2.0 MB/s eta 0:00:16
#    -------- ------------------------------- 7.6/37.3 MB 2.0 MB/s eta 0:00:16
#    -------- ------------------------------- 8.1/37.3 MB 2.0 MB/s eta 0:00:15
#    -------- ------------------------------- 8.4/37.3 MB 2.0 MB/s eta 0:00:15
#    --------- ------------------------------ 8.9/37.3 MB 2.0 MB/s eta 0:00:15
#    ---------- ----------------------------- 9.4/37.3 MB 2.0 MB/s eta 0:00:15
#    ---------- ----------------------------- 9.7/37.3 MB 2.0 MB/s eta 0:00:14
#    ---------- ----------------------------- 10.2/37.3 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 10.7/37.3 MB 2.0 MB/s eta 0:00:14
#    ----------- ---------------------------- 11.0/37.3 MB 2.0 MB/s eta 0:00:14
#    ------------ --------------------------- 11.5/37.3 MB 2.0 MB/s eta 0:00:13
#    ------------ --------------------------- 12.1/37.3 MB 2.0 MB/s eta 0:00:13
#    ------------- -------------------------- 12.3/37.3 MB 2.0 MB/s eta 0:00:13
#    ------------- -------------------------- 12.8/37.3 MB 2.0 MB/s eta 0:00:13
#    -------------- ------------------------- 13.4/37.3 MB 2.0 MB/s eta 0:00:12
#    -------------- ------------------------- 13.6/37.3 MB 2.0 MB/s eta 0:00:12
#    --------------- ------------------------ 14.2/37.3 MB 2.0 MB/s eta 0:00:12
#    --------------- ------------------------ 14.7/37.3 MB 2.0 MB/s eta 0:00:12
#    ---------------- ----------------------- 14.9/37.3 MB 2.0 MB/s eta 0:00:12
#    ---------------- ----------------------- 15.5/37.3 MB 2.0 MB/s eta 0:00:11
#    ---------------- ----------------------- 15.7/37.3 MB 2.0 MB/s eta 0:00:11
#    ----------------- ---------------------- 16.3/37.3 MB 2.0 MB/s eta 0:00:11
#    ----------------- ---------------------- 16.8/37.3 MB 2.0 MB/s eta 0:00:11
#    ------------------ --------------------- 17.0/37.3 MB 2.0 MB/s eta 0:00:11
#    ------------------ --------------------- 17.6/37.3 MB 2.0 MB/s eta 0:00:10
#    ------------------- -------------------- 17.8/37.3 MB 2.0 MB/s eta 0:00:10
#    ------------------- -------------------- 18.4/37.3 MB 2.0 MB/s eta 0:00:10
#    ------------------- -------------------- 18.6/37.3 MB 2.0 MB/s eta 0:00:10
#    -------------------- ------------------- 19.1/37.3 MB 2.0 MB/s eta 0:00:10
#    --------------------- ------------------ 19.7/37.3 MB 2.0 MB/s eta 0:00:09
#    --------------------- ------------------ 19.9/37.3 MB 2.0 MB/s eta 0:00:09
#    --------------------- ------------------ 20.4/37.3 MB 2.0 MB/s eta 0:00:09
#    ---------------------- ----------------- 20.7/37.3 MB 2.0 MB/s eta 0:00:09
#    ---------------------- ----------------- 21.2/37.3 MB 2.0 MB/s eta 0:00:09
#    ----------------------- ---------------- 21.5/37.3 MB 2.0 MB/s eta 0:00:08
#    ----------------------- ---------------- 22.0/37.3 MB 2.0 MB/s eta 0:00:08
#    ----------------------- ---------------- 22.0/37.3 MB 2.0 MB/s eta 0:00:08
#    ------------------------ --------------- 22.8/37.3 MB 2.0 MB/s eta 0:00:08
#    ------------------------ --------------- 23.1/37.3 MB 2.0 MB/s eta 0:00:08
#    ------------------------- -------------- 23.3/37.3 MB 2.0 MB/s eta 0:00:08
#    ------------------------- -------------- 23.6/37.3 MB 2.0 MB/s eta 0:00:08
#    ------------------------- -------------- 23.9/37.3 MB 1.9 MB/s eta 0:00:07
#    ------------------------- -------------- 24.1/37.3 MB 1.9 MB/s eta 0:00:07
#    -------------------------- ------------- 24.6/37.3 MB 1.9 MB/s eta 0:00:07
#    -------------------------- ------------- 24.9/37.3 MB 1.9 MB/s eta 0:00:07
#    -------------------------- ------------- 25.2/37.3 MB 1.9 MB/s eta 0:00:07
#    --------------------------- ------------ 25.4/37.3 MB 1.9 MB/s eta 0:00:07
#    --------------------------- ------------ 25.7/37.3 MB 1.9 MB/s eta 0:00:07
#    ---------------------------- ----------- 26.2/37.3 MB 1.9 MB/s eta 0:00:06
#    ---------------------------- ----------- 26.5/37.3 MB 1.9 MB/s eta 0:00:06
#    ---------------------------- ----------- 26.7/37.3 MB 1.9 MB/s eta 0:00:06
#    ---------------------------- ----------- 27.0/37.3 MB 1.9 MB/s eta 0:00:06
#    ----------------------------- ---------- 27.3/37.3 MB 1.9 MB/s eta 0:00:06
#    ----------------------------- ---------- 27.8/37.3 MB 1.9 MB/s eta 0:00:06
#    ------------------------------ --------- 28.0/37.3 MB 1.9 MB/s eta 0:00:05
#    ------------------------------ --------- 28.3/37.3 MB 1.9 MB/s eta 0:00:05
#    ------------------------------ --------- 28.6/37.3 MB 1.9 MB/s eta 0:00:05
#    ------------------------------ --------- 28.8/37.3 MB 1.8 MB/s eta 0:00:05
#    ------------------------------- -------- 29.4/37.3 MB 1.8 MB/s eta 0:00:05
#    ------------------------------- -------- 29.6/37.3 MB 1.8 MB/s eta 0:00:05
#    -------------------------------- ------- 29.9/37.3 MB 1.8 MB/s eta 0:00:05
#    -------------------------------- ------- 30.1/37.3 MB 1.8 MB/s eta 0:00:04
#    -------------------------------- ------- 30.7/37.3 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 30.9/37.3 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 31.2/37.3 MB 1.8 MB/s eta 0:00:04
#    --------------------------------- ------ 31.5/37.3 MB 1.8 MB/s eta 0:00:04
#    ---------------------------------- ----- 32.0/37.3 MB 1.8 MB/s eta 0:00:03
#    ---------------------------------- ----- 32.2/37.3 MB 1.8 MB/s eta 0:00:03
#    ---------------------------------- ----- 32.5/37.3 MB 1.8 MB/s eta 0:00:03
#    ----------------------------------- ---- 33.0/37.3 MB 1.8 MB/s eta 0:00:03
#    ----------------------------------- ---- 33.3/37.3 MB 1.8 MB/s eta 0:00:03
#    ----------------------------------- ---- 33.6/37.3 MB 1.8 MB/s eta 0:00:03
#    ------------------------------------ --- 34.1/37.3 MB 1.8 MB/s eta 0:00:02
#    ------------------------------------ --- 34.3/37.3 MB 1.8 MB/s eta 0:00:02
#    ------------------------------------- -- 34.9/37.3 MB 1.8 MB/s eta 0:00:02
#    ------------------------------------- -- 35.1/37.3 MB 1.8 MB/s eta 0:00:02
#    -------------------------------------- - 35.7/37.3 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 35.9/37.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  36.4/37.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  37.0/37.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 1.8 MB/s  0:00:20
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
#
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    
    ## Note: You can add different data transformation techniques such as Scaler, PCA and all
    #You can perform all kinds of EDA in ML cycle here before passing this data to the model

    # I am only adding train_test_spliting cz this data is already cleaned up


    def train_test_spliting(self):
        data = pd.read_csv(self.config.data_path)

        # Split the data into training and test sets. (0.75, 0.25) split.
        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"),index = False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"),index = False)

        logger.info("Splited data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_spliting()
except Exception as e:
    raise e
# Out:
# [2026-03-25 02:16:56,777: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-03-25 02:16:56,790: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-03-25 02:16:56,796: INFO: common: yaml file: schema.yaml loaded successfully]
# [2026-03-25 02:16:56,802: INFO: common: created directory at: artifacts]
# [2026-03-25 02:16:56,805: INFO: common: created directory at: artifacts/data_transformation]
# [2026-03-25 02:16:56,893: INFO: 741865018: Splited data into training and test sets]
# [2026-03-25 02:16:56,895: INFO: 741865018: (1199, 12)]
# [2026-03-25 02:16:56,896: INFO: 741865018: (400, 12)]
# (1199, 12)
# (400, 12)
